# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
happiness=pd.read_csv('C:/Users/D17297/Downloads/0.05a65o3cwn9t0.b53bayxyqtvhappiness_report.csv')

# %%
happiness
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
Mexico = happiness[(happiness['Country or region']=='Mexico')]
Mexico.set_index('Country or region',inplace=True)
Mexico
# Out:
#                    Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Mexico                       23  6.595            1.07           1.323
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Mexico                               0.861                         0.433
#
#                    Generosity  Perceptions of corruption
# Country or region
# Mexico                  0.074                      0.073

# %%
plt.hist(happiness['Score'])
props_bbox={'boxstyle': 'circle', 'facecolor':'red', 'alpha':0.3}
plt.text(Mexico['Score'],0,'MEX',bbox=props_bbox, fontdict={'color':'white'})
plt.title('World Happines Report')
plt.xlabel('Score')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
happiness['Healthy life expectancy'].plot.box()
plt.title('World Happines Report')
props_bbox={'boxstyle': 'circle', 'facecolor':'red', 'alpha':0.3}
plt.annotate('MEX',xy=(1,Mexico['Healthy life expectancy']), xytext=(1.2,1),arrowprops=dict(arrowstyle='<->', connectionstyle='angle3'),bbox=props_bbox)
# Out:
# Text(1.2, 1, 'MEX')

# %%
Mexico1=Mexico.drop(['Overall rank','Score'],axis=1).T
Mexico1
plt.figure(figsize=(12,12))
plt.title('Contribution in Mexico Happiness Score')
plt.pie('Mexico',labels=Mexico1.index, data=Mexico1,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x160a7a9e608>,
# ...
#  [Text(0.7036080672320641, 0.8455386967643523, 'GDP per capita'),
#   Text(-1.0495618790668264, 0.32927171456065374, 'Social support'),
#   Text(-0.09362648306924604, -1.0960082489051277, 'Healthy life expectancy'),
#   Text(0.910527556193128, -0.6172030212279996, 'Freedom to make life choices'),
#   Text(1.0821750621015562, -0.1972235659486288, 'Generosity'),
#   Text(1.0980326705484382, -0.06575906331651368, 'Perceptions of corruption')],
#  [Text(0.38378621849021677, 0.4612029255078285, '27.91%'),
#   Text(-0.5724882976728143, 0.1796027533967202, '34.51%'),
#   Text(-0.05106899076504329, -0.5978226812209787, '22.46%'),
#   Text(0.49665139428716065, -0.3366561933970907, '11.29%'),
#   Text(0.5902773066008488, -0.10757649051743388, '1.93%'),
#   Text(0.5989269112082389, -0.03586857999082564, '1.90%')])

# %%
happiness.sort_values('Score', inplace=True)

# %%
happiness1=pd.concat([happiness[-1:],happiness[happiness['Country or region']=='Mexico'],happiness[happiness['Country or region']=='Norway'],happiness[happiness['Country or region']=='Central African Republic'],happiness[:1]])
happiness1.set_index('Country or region',inplace=True)
happiness1=happiness1.drop(['Overall rank','Score'],axis=1).T
happiness1
# Out:
# Country or region             Finland  Mexico  Norway  \
# GDP per capita                  1.340   1.070   1.488
# Social support                  1.587   1.323   1.582
# Healthy life expectancy         0.986   0.861   1.028
# Freedom to make life choices    0.596   0.433   0.603
# Generosity                      0.153   0.074   0.271
# Perceptions of corruption       0.393   0.073   0.341
#
# Country or region             Central African Republic  South Sudan
# GDP per capita                                   0.026        0.306
# Social support                                   0.000        0.575
# Healthy life expectancy                          0.105        0.295
# Freedom to make life choices                     0.225        0.010
# Generosity                                       0.235        0.202
# Perceptions of corruption                        0.035        0.091

# %%
happiness1.plot(kind='bar')
plt.title('World Happines Report')
# Out:
# Text(0.5, 1.0, 'World Happines Report')

# %%
fig,axs = plt.subplots(2,3,figsize=(15,9))
happiness.plot(kind='scatter',x='Score', y='GDP per capita',c='green',ax=axs[0,0])
happiness.plot(kind='scatter',x='Score', y='Social support',c='green',ax=axs[0,1])
happiness.plot(kind='scatter',x='Score', y='Healthy life expectancy',c='green',ax=axs[0,2])
happiness.plot(kind='scatter',x='Score', y='Freedom to make life choices',c='green',ax=axs[1,0])
happiness.plot(kind='scatter',x='Score', y='Generosity',c='green',ax=axs[1,1])
happiness.plot(kind='scatter',x='Score', y='Perceptions of corruption',c='green',ax=axs[1,2])
fig.suptitle('Contribution in Happiness Score')
# Out:
# Text(0.5, 0.98, 'Contribution in Happiness Score')

# %%
happiness2=happiness.drop(['Overall rank','Score','Country or region'],axis=1)
sns.heatmap(round(happiness2.corr(),2),annot=True)

# %%
metadata=pd.read_csv('C:/Users/D17297/Downloads/Metadata.csv')
metadata
metadata.rename(columns={'TableName':'Country or region'},inplace=True)

# %%
happiness3=happiness.merge(metadata,on='Country or region')
happiness3
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0             156               South Sudan  2.853           0.306
# 1             155  Central African Republic  3.083           0.026
# 2             154               Afghanistan  3.203           0.350
# 3             153                  Tanzania  3.231           0.476
# 4             152                    Rwanda  3.334           0.359
# ..            ...                       ...    ...             ...
# 131             5               Netherlands  7.488           1.396
# 132             4                   Iceland  7.494           1.380
# 133             3                    Norway  7.554           1.488
# 134             2                   Denmark  7.600           1.383
# 135             1                   Finland  7.769           1.340
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             0.575                    0.295                         0.010
# ...

# %%
ax=sns.barplot(x='Region',y='Score',data=happiness3,estimator=np.mean)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.title('World Happines Report')
plt.xlabel('Region')
# Out:
# Text(0.5, 0, 'Region')
